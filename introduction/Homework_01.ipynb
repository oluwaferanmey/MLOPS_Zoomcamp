# %%
# Install pyarrow or fastparquet
# !pip install pyarrow

import pandas as pd
from sklearn.feature_extraction import DictVectorizer

# Read the Parquet file
jan_records = pd.read_parquet("https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-01.parquet")
feb_records = pd.read_parquet("https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-02.parquet")

# %%
"""
Question 1 : Read the data for January. How many columns are there?
"""
jan_records
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1               2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2               2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3               1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4               2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
# ...           ...                  ...                   ...              ...
# 3066761         2  2023-01-31 23:58:34   2023-02-01 00:12:33              NaN
# 3066762         2  2023-01-31 23:31:09   2023-01-31 23:50:36              NaN
# 3066763         2  2023-01-31 23:01:05   2023-01-31 23:25:36              NaN
# 3066764         2  2023-01-31 23:40:00   2023-01-31 23:53:00              NaN
# 3066765         2  2023-01-31 23:07:32   2023-01-31 23:21:56              NaN
#
# ...

# %%
feb_records
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2023-02-01 00:32:53   2023-02-01 00:34:34              2.0
# 1               2  2023-02-01 00:35:16   2023-02-01 00:35:30              1.0
# 2               2  2023-02-01 00:35:16   2023-02-01 00:35:30              1.0
# 3               1  2023-02-01 00:29:33   2023-02-01 01:01:38              0.0
# 4               2  2023-02-01 00:12:28   2023-02-01 00:25:46              1.0
# ...           ...                  ...                   ...              ...
# 2913950         2  2023-02-28 23:46:00   2023-03-01 00:05:00              NaN
# 2913951         2  2023-02-28 23:26:02   2023-02-28 23:37:10              NaN
# 2913952         2  2023-02-28 23:24:00   2023-02-28 23:38:00              NaN
# 2913953         2  2023-02-28 23:03:00   2023-02-28 23:10:00              NaN
# 2913954         2  2023-02-28 23:03:03   2023-02-28 23:12:51              NaN
#
# ...

# %%
"""
Question 2 : What's the standard deviation of the trips duration in January?
"""
# converts from string to datetime
jan_records["tpep_pickup_datetime"] = pd.to_datetime(jan_records["tpep_pickup_datetime"]) # to_datetime converts the column datatype to datetime
jan_records["tpep_dropoff_datetime"] = pd.to_datetime(jan_records["tpep_dropoff_datetime"])

# calculate trip duration
jan_records["duration"] = jan_records["tpep_dropoff_datetime"] - jan_records["tpep_pickup_datetime"]

# Convert trip duration to total minutes
jan_records['duration'] = jan_records['duration'].dt.total_seconds() / 60

# calculates the standard deviation of the trips duration in January
std_dev = jan_records['duration'].std()

print(std_dev)
# Out:
# 42.594351241920904

# %%
"""
Question 3 :
Dropping Outliers; keeping only the records where the duration was between 1 and 60 minutes (inclusive).
calculates what fraction of the records left after the outliers were dropped?
"""
# Filter records where duration is between 1 and 60 minutes (inclusive)
filtered_records = jan_records[(jan_records['duration'] >= 1) & (jan_records['duration'] <= 60)]

# Calculate the fraction of records left after filtering
fraction_left = len(filtered_records) / len(jan_records)

print(round(fraction_left * 100))
# Out:
# 98

# %%
"""
Question 4: 
Let's apply one-hot encoding to the pickup and dropoff location IDs. We'll use only these two features for our model.

Turn the dataframe into a list of dictionaries (remember to re-cast the ids to strings - otherwise it will label encode them)
Fit a dictionary vectorizer
Get a feature matrix from it
What's the dimensionality of this matrix (number of columns)?
"""
#converts datatype from integger to string
jan_records["PULocationID"] = jan_records["PULocationID"].astype(str)
jan_records["DOLocationID"] = jan_records["DOLocationID"].astype(str)

# intialize the vectorizer
dv = DictVectorizer ()

# feature is the independent variable while label is the dependent variable
features = ["PULocationID","DOLocationID"]
label = ["trip_distance"]

# %%
train_dict = jan_records[features + label].to_dict(orient = 'records')

# %%
print(train_dict)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
